# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2,2,1)
ax1.set_title("Wykres nr 1")

ax2 = fig.add_subplot(2,2,2)
ax2.set_title("Wykres nr 2")

ax3 = fig.add_subplot(2,2,3)
ax3.set_title("Wykres nr 3")

ax4 = fig.add_subplot(2,2,4)
ax4.set_title("Wykres nr 4")

fig.subplots_adjust(wspace=0.2, hspace=0.3)

# %%
fig = plt.figure()
ax = []
for i in range(1,5):
    iax = fig.add_subplot(2,2,i)
    iax.set_title("Wykres nr "+ str(i))
    ax.append(iax)
       
ax
# Out:
# [<Axes: title={'center': 'Wykres nr 1'}>,
#  <Axes: title={'center': 'Wykres nr 2'}>,
#  <Axes: title={'center': 'Wykres nr 3'}>,
#  <Axes: title={'center': 'Wykres nr 4'}>]
